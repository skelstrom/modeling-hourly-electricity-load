# %%
# --- 00 Environment Setup (Colab) ---
# Installs pinned dependencies and avoids NumPy/Pandas/PyArrow binary mismatches.

# --- Mount Google Drive and set up repo environment ---
from google.colab import drive
from pathlib import Path
import sys, os

# Mount Google Drive
drive.mount("/content/drive", force_remount=True)

REQ = "/content/drive/MyDrive/Github_Repo_Collection/Modeling_Hourly_Electricity_Load_with_Exogenous_Climate_and_Economic_Factors/requirements.txt"

# Remove common conflicting preinstalls
# !pip uninstall -y -q numpy pandas pyarrow

# Install pinned requirements
# !pip install -q --no-cache-dir --force-reinstall -r "{REQ}"

print("✅ Installed pinned requirements. Now restart runtime: Runtime → Restart runtime")
# Out:
# Mounted at /content/drive
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 2.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 16.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 152.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 45.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 14.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 85.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 73.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 103.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 MB 99.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 39.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 34.7 MB/s eta 0:00:00
# ...

# %%
import numpy as np, pandas as pd, pyarrow, duckdb
import sklearn, statsmodels, lightgbm, optuna

print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("PyArrow:", pyarrow.__version__)
print("DuckDB:", duckdb.__version__)
print("sklearn:", sklearn.__version__)
print("statsmodels:", statsmodels.__version__)
print("lightgbm:", lightgbm.__version__)
print("optuna:", optuna.__version__)
# Out:
# NumPy: 2.0.2
# Pandas: 2.2.2
# PyArrow: 18.1.0
# DuckDB: 1.3.2
# sklearn: 1.6.1
# statsmodels: 0.14.6
# lightgbm: 4.6.0
# optuna: 3.6.1
